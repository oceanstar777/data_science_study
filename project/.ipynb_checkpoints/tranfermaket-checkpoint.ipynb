# %% [markdown]
# ### Transfer markt 크롤링
# - 첫페이지와 두번째 페이지 50명 정보

# %%
#필요한 라이브러리 불러오기
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

# %%
#requests.get()으로 url정보 요청하기
headers = {'User-Agent':"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/95.0.4638.69 Safari/537.36"}

url = "https://www.transfermarkt.com/spieler-statistik/wertvollstespieler/marktwertetop"

r = requests.get(url,headers = headers)
r.status_code
#200 이 나오면 성공
# Out:
# 200

# %%
#BeautifuSoup()으로 웹페이지 분석 준비하기
soup = BeautifulSoup(r.content,'html.parser')
#r.content 대신 r.text도 가능
print(soup)
# Out:
# <!DOCTYPE html>
#
# <html class="no-js" lang="en">
# <head>
# <script type="text/javascript">
#     !function () { var e = function () { var e, t = "__tcfapiLocator", a = [], n = window; for (; n;) { try { if (n.frames[t]) { e = n; break } } catch (e) { } if (n === window.top) break; n = n.parent } e || (!function e() { var a = n.document, r = !!n.frames[t]; if (!r) if (a.body) { var i = a.createElement("iframe"); i.style.cssText = "display:none", i.name = t, a.body.appendChild(i) } else setTimeout(e, 5); return !r }(), n.__tcfapi = function () { for (var e, t = arguments.length, n = new Array(t), r = 0; r < t; r++)n[r] = arguments[r]; if (!n.length) return a; if ("setGdprApplies" === n[0]) n.length > 3 && 2 === parseInt(n[1], 10) && "boolean" == typeof n[3] && (e = n[3], "function" == typeof n[2] && n[2]("set", !0)); else if ("ping" === n[0]) { var i = { gdprApplies: e, cmpLoaded: !1, cmpStatus: "stub" }; "function" == typeof n[2] && n[2](i) } else a.push(n) }, n.addEventListener("message", (function (e) { var t = "string" == typeof e.data, a = {}; try { a = t ? JSON.parse(e.data) : e.data } catch (e) { } var n = a.__tcfapiCall; n && window.__tcfapi(n.command, n.version, (function (a, r) { var i = { __tcfapiReturn: { returnValue: a, success: r, callId: n.callId } }; t && (i = JSON.stringify(i)), e.source.postMessage(i, "*") }), n.parameter) }), !1)) }; "undefined" != typeof module ? module.exports = e : e() }();
# </script>
# <script>
# window._sp_ = {
#     config: {"accountId":1254,"propertyId":7427,"baseEndpoint":"https://cdn.privacy-mgmt.com"}}
# </script>
# <script src="https://cdn.privacy-mgmt.com/wrapperMessagingWithoutDetection.js"></script>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="x-ua-compatible"/>
# <meta content="telephone=no" name="format-detection"/>
# <meta content="#1a3151" name="theme-color">
# <link href="/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="/favicon-16x16.png" rel="shortcut icon" sizes="16x16"/>
# <link href="/android-chrome-192x192.png" rel="shortcut icon" sizes="192x192"/>
# <link href="/apple-touch-icon-152x152.png" rel="apple-touch-icon-precomposed"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=2.0, user-scalable=no" name="viewport">
# <meta content="article" property="og:type"/>
# <meta content="https://tmssl.akamaized.net/images/tm_logo.png" property="og:image"/>
# <meta content="" property="og:description"/>
# <meta content="Most valuable players" property="og:title"/>
# <meta content="https://www.transfermarkt.com/spieler-statistik/wertvollstespieler/marktwertetop" property="og:url"/>
# <link href="https://www.transfermarkt.de/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="de" rel="alternate">
# <link href="https://www.transfermarkt.de/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="de-LU" rel="alternate">
# <link href="https://www.transfermarkt.at/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="de-AT" rel="alternate">
# <link href="https://www.transfermarkt.ch/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="de-CH" rel="alternate"/>
# <link href="https://www.transfermarkt.com.tr/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="tr" rel="alternate"/>
# <link href="https://www.transfermarkt.it/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="it-CH" rel="alternate"/>
# <link href="https://www.transfermarkt.it/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="it" rel="alternate"/>
# <link href="https://www.transfermarkt.pl/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="pl" rel="alternate"/>
# <link href="https://www.transfermarkt.co.uk/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="en-GB" rel="alternate"/>
# <link href="https://www.transfermarkt.co.uk/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="en-IE" rel="alternate"/>
# <link href="https://www.transfermarkt.es/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="es" rel="alternate"/>
# <link href="https://www.transfermarkt.es/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="es-ES" rel="alternate"/>
# <link href="https://www.transfermarkt.es/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="es-CL" rel="alternate"/>
# <link href="https://www.transfermarkt.es/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="es-VE" rel="alternate"/>
# <link href="https://www.transfermarkt.es/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="es-PE" rel="alternate"/>
# <link href="https://www.transfermarkt.es/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="es-EC" rel="alternate"/>
# <link href="https://www.transfermarkt.es/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="es-CU" rel="alternate"/>
# <link href="https://www.transfermarkt.nl/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="nl" rel="alternate"/>
# <link href="https://www.transfermarkt.pt/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="pt" rel="alternate"/>
# <link href="https://www.transfermarkt.ru/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="ru" rel="alternate"/>
# <link href="https://www.transfermarkt.fr/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="fr-CH" rel="alternate"/>
# <link href="https://www.transfermarkt.fr/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="fr" rel="alternate"/>
# <link href="https://www.transfermarkt.fr/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="fr-CA" rel="alternate"/>
# <link href="https://www.transfermarkt.fr/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="fr-CI" rel="alternate"/>
# <link href="https://www.transfermarkt.fr/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="fr-LU" rel="alternate"/>
# <link href="https://www.transfermarkt.fr/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="fr-BE" rel="alternate"/>
# <link href="https://www.transfermarkt.com.br/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="pt-BR" rel="alternate"/>
# <link href="https://www.transfermarkt.us/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="en-US" rel="alternate"/>
# <link href="https://www.transfermarkt.us/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="en-CA" rel="alternate"/>
# <link href="https://www.transfermarkt.co.in/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="en-IN" rel="alternate"/>
# <link href="https://www.transfermarkt.co.za/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="en-ZA" rel="alternate"/>
# <link href="https://www.transfermarkt.com/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="x-default" rel="alternate"/>
# <link href="https://www.transfermarkt.com/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="en" rel="alternate"/>
# <link href="https://www.transfermarkt.be/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="nl-BE" rel="alternate"/>
# <link href="https://www.transfermarkt.com.ar/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="es-AR" rel="alternate"/>
# <link href="https://www.transfermarkt.mx/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="es-MX" rel="alternate"/>
# <link href="https://www.transfermarkt.co/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="es-CO" rel="alternate"/>
# <link href="https://www.transfermarkt.my/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="ms" rel="alternate"/>
# <link href="https://www.transfermarkt.jp/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="ja" rel="alternate"/>
# <link href="https://www.transfermarkt.co.id/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="id" rel="alternate"/>
# <link href="https://www.transfermarkt.com/spieler-statistik/wertvollstespieler/marktwertetop?page=2" rel="next"/>
# <link href="https://tmssl.akamaized.net/css/stylesheets/menue.css?lm=1635406395" rel="stylesheet" type="text/css"/>
# <link href="https://tmssl.akamaized.net/css/stylesheets/tm-grid.css?lm=1635406395" rel="stylesheet" type="text/css"/>
# <link href="https://tmssl.akamaized.net/css/stylesheets/main.css?lm=1635406395" rel="stylesheet" type="text/css"/>
# <link href="https://tmssl.akamaized.net/styles/tm-main.css?lm=1635406290" rel="stylesheet" type="text/css"/>
# <link href="https://tmssl.akamaized.net/assets/b7c5571cf8957553f95f6d9069eaed67/jui/css/base/jquery-ui.css?lm=1635406406" rel="stylesheet" type="text/css"/>
# <link href="https://tmssl.akamaized.net/css/stylesheets/main_desktop.css?lm=1635406395" rel="stylesheet" type="text/css"/>
# <link href="https://tmssl.akamaized.net/css/sprite-main.css?lm=1635406395" rel="stylesheet" type="text/css"/>
# <link href="https://tmssl.akamaized.net/css/chosen.css?lm=1635406395" rel="stylesheet" type="text/css"/>
# <link href="https://tmssl.akamaized.net/css/jquery-ui-1.10.4.custom.css?lm=1635406395" rel="stylesheet" type="text/css"/>
# <link href="https://tmssl.akamaized.net/css/jquery-ui-1.10.4.tm-theme.css?lm=1635406395" rel="stylesheet" type="text/css"/>
# <link href="https://tmssl.akamaized.net/css/stylesheets/main_werbung.css?lm=1635406395" rel="stylesheet" type="text/css"/>
# <link href="https://tmssl.akamaized.net/css/shortclasses.css?lm=1635406395" rel="stylesheet" type="text/css"/>
# <link href="https://tmssl.akamaized.net/css/print.css?_sn=1?lm=1635406395" media="print" rel="stylesheet" type="text/css"/>
# <link href="https://tmssl.akamaized.net/css/desktop.css?lm=1635406395" rel="stylesheet" type="text/css"/>
# <link href="https://tmssl.akamaized.net/css/domainspezifisch/desktop-com.css?lm=1635406395" rel="stylesheet" type="text/css"/>
# <link href="https://tmssl.akamaized.net/css/stylesheets/gridview.css?lm=1635406395" rel="stylesheet" type="text/css"/>
# <link href="https://tmssl.akamaized.net/css/stylesheets/paginator.css?lm=1635406395" rel="stylesheet" type="text/css"/>
# <link href="https://tmssl.akamaized.net/css/statistiken.css?lm=1635406395" rel="stylesheet" type="text/css"/>
# <link href="https://tmssl.akamaized.net/assets/bdb39bc7538f732f9833170435d23c28/css/tooltipster.css?lm=1635406406" rel="stylesheet" type="text/css"/>
# <script src="https://tmssl.akamaized.net/js/vendor/jquery.min.js?lm=1635406377" type="text/javascript"></script>
# <script src="https://tmssl.akamaized.net/assets/b7c5571cf8957553f95f6d9069eaed67/jquery.ba-bbq.min.js?lm=1635406406" type="text/javascript"></script>
# <script src="https://tmssl.akamaized.net/assets/b344ec51bd68be8ed48379c9e69eb01d/js/jquery.scrollTo.min.js?lm=1635406406" type="text/javascript"></script>
# <script src="https://tmssl.akamaized.net/assets/b344ec51bd68be8ed48379c9e69eb01d/js/elinkpagermobile.js?lm=1635406406" type="text/javascript"></script>
# <script src="https://tmssl.akamaized.net/js/localStorage.js?lm=1635406377" type="text/javascript"></script>
# <script src="https://tmssl.akamaized.net/js/foundation.js?lm=1635406377" type="text/javascript"></script>
# <script src="https://tmssl.akamaized.net/js/main.js?lm=1635406378" type="text/javascript"></script>
# <script src="https://tmssl.akamaized.net/js/jquery-ui-1.10.4.custom.min.js?lm=1635406378" type="text/javascript"></script>
# <script src="https://tmssl.akamaized.net/js/clipboard.min.js?lm=1635406377" type="text/javascript"></script>
# <script src="https://tmssl.akamaized.net/js/chosen.ajaxaddition.jquery.js?lm=1635406378" type="text/javascript"></script>
# <script src="https://tmssl.akamaized.net/js/functions.js?lm=1635406377" type="text/javascript"></script>
# <script src="https://tmssl.akamaized.net/js/main_desktop.js?lm=1635406377" type="text/javascript"></script>
# <script src="https://tmssl.akamaized.net/js/chosen.jquery.js?lm=1635406378" type="text/javascript"></script>
# <script src="https://tmssl.akamaized.net/assets/bdb39bc7538f732f9833170435d23c28/js/jquery.tooltipster.js?lm=1635406406" type="text/javascript"></script>
# <title>Most valuable players | Transfermarkt</title>
# <script src="https://tmsi.akamaized.net/js/globals/tm-global-elements.esm.js" type="module">
# /*<![CDATA[*/
#
# /*]]>*/
# </script><script nomodule="" src="https://tmsi.akamaized.net/js/globals/tm-global-elements.js" type="text/javascript">
# /*<![CDATA[*/
#
# /*]]>*/
# </script>
# <script type="text/javascript">
#    tmData = {
#        loggedIn : "0",
#        tmTraffic: "0",
#    };
# </script>
# <script>// Set to the same value as the web property used on the site
# 		var gaProperty = 'UA-3816204-13';
#
# 		// Disable tracking if the opt-out cookie exists.
# 		var disableStr = 'ga-disable-' + gaProperty;
# 		if (document.cookie.indexOf(disableStr + '=true') > -1) {
# 			window[disableStr] = true;
# 		}
#
# 		// Opt-out function
# 		function gaOptout() {
# 			document.cookie = disableStr + '=true; expires=Thu, 31 Dec 2099 23:59:59 UTC; path=/';
# 			window[disableStr] = true;
# 		}</script>
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-3816204-13"></script>
# <script>
# 	window.dataLayer = window.dataLayer || [];
# 	function gtag() { dataLayer.push(arguments); }
#    gtag('set', 'linker', { 'domains': [/^transfermarkt\.(com|de|nl|it|at|ch|es|fr|com\.tr|pt|tv|pl|co\.uk)$/]});
#    gtag('js', new Date());
#    gtag('set',
#   {
#     'custom_map': {
#                     'dimension1': 'loggedIn',
#                     'dimension2': 'tmTraffic'
#                 }
#   });
#         gtag('config', 'UA-3816204-13', {
#                 'anonymize_ip': true,
#                 'transport_type': 'beacon',
#                 'content_group1': 'statistik',
#                 'content_group2': 'global',
#                 'content_group3': 'wertvollstespieler',
#                 'content_group4': '',
#                 'loggedIn': tmData.loggedIn,
#                 'tmTraffic': tmData.tmTraffic
#             });
#    function tmEvent(category, action, label) {
#                 gtag('event',
#                     action,
#                     {
#                         'event_category': category,
#                         'event_label': label
#                     }
#                 );
#             }
#
#             function tmTiming(value, name, event_category, event_label) {
#                 gtag('event', 'timing_complete', {
#                     name,
#                     value,
#                     event_category,
#                     event_label
#                 });
#             }
#
# 	</script><!--  SZM 2.0 (IVW/AGOF) -->
# <script src="https://script.ioam.de/iam.js" type="text/javascript"></script> <script src="https://tmssl.akamaized.net//ads/ads.js" type="text/javascript"></script>
# <script type="text/javascript">
#         window.tmGaId = "UA-3816204-13";
#         if (self == top) {
#             document.documentElement.style.display = 'block';
#         } else {
#             top.location = self.location;
#         }
#     </script>
# <noscript>
# <style>
#             html body *:not(.noscript) {
#                 display: none;
#             }
#         </style>
# <div class="noscript">
#             To use this site, please enable Javascript.        </div>
# </noscript>
# <!--Tisoomi-->
# <script type="text/javascript">
# /* 08150306 */ !function(u,e){function n(u,e){var n=fu(u);if(!n)return n;if(""!=e)for(var t=0;t<e.length;t++){var i=v(e,t);"^"==i&&(n=n.parentNode),"<"==i&&(n=n.previousElementSibling),">"==i&&(n=n.nextElementSibling),"y"==i&&(n=n.firstChild)}return n}function t(u,e){var n=iu(e);return{x:u.clientX-n.left,y:u.clientY-n.top}}function i(u){for(var e=0,n=0;u;)e+=u.offsetLeft+u.clientLeft,n+=u.offsetTop+u.clientTop,u=u.offsetParent;return{x:e,y:n}}function l(u,e){var n=0,t=0,l=i(e);return(u.pageX||u.pageY)&&(n=u.pageX,t=u.pageY),(u.clientX||u.clientY)&&(n=u.clientX+document.body.scrollLeft+document.documentElement.scrollLeft,t=u.clientY+document.body.scrollTop+document.documentElement.scrollTop),n-=l.x,t-=l.y,{x:n,y:t}}function r(u,e){return tu(e)?t(u,e):l(u,e)}function d(u,e){u.addEventListener?m(u,"click",e,!0):u.attachEvent&&u.attachEvent("onclick",function(){return e.call(u,window.event)})}function o(e,n){return u[z("c2V0VGltZW91dA==")](e,n)}function c(u){return parseInt(u.toString().split(".")[0],10)}function v(u,e){return u[e]}function s(){return Pu=(Su*Pu+Ou)%Uu}function p(){return s()/(Uu-1)}function f(){return p()}function a(u,e){return u>e?u:e}function h(){for(var u="",e=65;e<91;e++)u+=w(e);for(var e=97;e<123;e++)u+=w(e);return u}function w(u){return v(" !\"#$%&'()*+,-./0123456789:;<=>?@ABCDEFGHIJKLMNOPQRSTUVWXYZ["+v("\\\\",0)+"]^_`abcdefghijklmnopqrstuvwxyz{|}~",u-32)}function z(u){var e,n,t,i,l,r,d,o=h()+"0123456789+/=",c="",s=0;for(u=u.replace(/[^A-Za-z0-9\+\/\=]/g,"");s<u.length;)i=o.indexOf(v(u,s++)),l=o.indexOf(v(u,s++)),r=o.indexOf(v(u,s++)),d=o.indexOf(v(u,s++)),e=i<<2|l>>4,n=(15&l)<<4|r>>2,t=(3&r)<<6|d,c+=w(e),64!=r&&(c+=w(n)),64!=d&&(c+=w(t));return c}function R(){try{return navigator.userAgent||navigator.vendor||window.opera}catch(u){return"unknown"}}function m(u,e,n,t){t=t||!1;try{u.addEventListener(e,n,t)}catch(t){u.attachEvent&&u.attachEvent("on"+e,n)}}function g(u){if(!u)return"";for(var e=z("ISIjJCUmJygpKissLS4vOjs8PT4/QFtcXV5ge3x9"),n="",t=0;t<u.length;t++){n+=e.indexOf(u[t])>-1?z("XA==")+u[t]:u[t]}return n}function x(u){if(!u)return"";var e="";return u.id&&u.id.length>0&&(e+="#"+g(u.id)),u.className&&u.className.length>0&&(e+="."+g(u.className).split(" ").filter(function(u){return u&&u.length>0}).join(".")),e}function k(u){Ku[u]=!1}function j(u,e){var n=Lu++;Ku[n]=!0;var t=function(e){return function(){u.call(null),Ku[n]&&o(t,e)}}(e);return o(t,e),n}function b(u){var e=!1;return Object.keys(u).forEach(function(n){e=e||u[n]}),!e}function y(u,e){return u&&(u.consents&&u.consents[e]||u.legitimateInterests&&u.legitimateInterests[e])}function q(e){return!!u.luucv6b8Flags.strictNCNA&&(y(e,2)&&y(e,7)&&y(e,9)&&y(e,10))}function T(u,e,n){var t=function(){return!!e()&&(n(),!0)};if(!t()){var i=j(function(){t()&&k(i)},250);t()}}function W(u){E(u)}function E(n){if(n.luucvb2esdl&&!n.luucv1a3Inject){n.luucv1a3Inject=!0,n.luucvd2aPc={},n.luucvc30Oc=[],n.luucv787Am={},n.luucv565Av={},n.luucv814Aw={},n.luucve63Rqr={},n.luucv87dRqq=[],n.luucv565Avt={},n.luucv99eEv={};var t=[];if(u.luucv6b8Flags.video){var i=fu(".news-content > .news-widget--container + p, .news-content > .news-widget--container + p, .spielerDatenContainer + .viewport-tracking + div");if(i){var l=D("div");pu(l,"TdXUzdo"),nu(l,"margin","20px 0px");var r=D("div");su(r,"dfbndrgl"),function(e){if(!e){u.luucv6b8Flags.videoUnblockingPaused=!1,u.luucv6b8Flags.goForImageAndIframeRecovery=!0,nu(i,"padding","initial");var n=D("div");$(n,"class","publisher-sh-spot"),$(n,"data-player","941cedf3-2100-46ab-a724-d5bdb0b520ce");var t=D("script");$(t,"onload","window.SpotSHTag=this"),$(t,"src","https://static.showheroes.com/publishertag.js"),$(t,"data-noad-passback-listener","window.luucv6b8Flags.video_displayAsBackfill = true;"),t.async=!0,du(i,l),B(l,n),B(l,t),ou(l,r)}}(u.luucv6b8Flags.ncna)}}if(!n.luucv6b8Flags.welect.eenabled||XZTHUWelect()){if(luucv6b8Flags.pt514ls){var d=luucv6b8Flags.ba8afit,o=luucv6b8Flags.mb501el||10,v=luucv6b8Flags.ig539BP,s=function(){var u=D("st ...
# var d=[Eu("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2U}STsrN5sJWHwQV[VffMEmzNnRsi34rsh\\V[NzOGJjl}2"+u.luucvb90Rnd+"XFRX6q{}gMQe|9FS4KtqT4sNkETyHX47o<YFsUUyi5UnUt31jli",-3),Eu("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2oMlYQWgkLXElEwSXIETy9Fu7]:l9lq}n4459ewngYKrt2"+u.luucvb90Rnd+"HSVf7\\vzKuY|3i;pRgKINkPJ|S8XzfJTmuPm8l9Lgf|PMnn1jli",-3),Eu("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2NKOFJxkmz:u]eFV5|9ev<\\ITK7376MJgqOerPxt]s5VL2"+u.luucvb90Rnd+"KFUYOk[OhRmvUn[FfyP\\:;<EV4iz7RpHKQ[Q:vwnGvt{QyE1jli",-3),Eu("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2IeHRm[qnytiz|4Tpg;p:prpNyHg3TYTSQ[tP8qnf;;<N2"+u.luucvb90Rnd+"]FS9Tse6I8FrJxh|UuMtutIG<IPJ{TVxT7FOkK{RPsqFq[G1jli",-3),Eu("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2pot5QuhWiZqeF<I|lFSHQkx[FNJ3qnI<zLL8Py9ZEN{M2"+u.luucvb90Rnd+"IGKf8fw3UoR[u6Os<QO]JrzVx:9pOvPv|Zuq6M]NK\\L<gV[1jli",-3),Eu("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2oSOlUE[67tw[]e7srS}USi][|JSZ\\[fee5w}6[jKuFJR2"+u.luucvb90Rnd+"]LHfGPpFzo4tiq<]mYYPluImS38ezzuETV3g}iZStf;55}N1jli",-3)],o=[Eu("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2LFxqEek;enzxTjQo6vNLuftHxVO7OGQF;l}yUhXU|FmK2"+u.luucvb90Rnd+"NZWSuo}Y;zeoYLFn]JqZKy6\\Sux3Uvx\\}FxOXGuzX}eWyly1jli",-3),Eu("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2kKgNEpN5s9sTYTh[HPjFnr]JO{sTGORjf8TU9i:oO]UQ2"+u.luucvb90Rnd+"SOK\\\\|pT{6eEOZ9]68f66zNQUM{L9j89ivu3J77TIij}Tz31jli",-3),Eu("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2\\P8jp8}<g7[WUGjet9ZI;Z[mzek<J[lhZ]rSZwXxLonr2"+u.luucvb90Rnd+"RFZqGqQ3ZVH7sTrS[]|jMKZN;kY[f6lVT8L}gsswFTRErje1jli",-3),Eu("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2QSieGmnrkKx[5QhXnZJpGoMZQlT3SZttGigOvoVN[HvV2"+u.luucvb90Rnd+"YLFuFpteJ6Lz6}vJftTVx8HWx];m|8gn]9xPs[]8KYIX<FS1jli",-3),Eu("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2vhp7XWo5[WgGnEtfEs8r6|{39{E4:UhJT9\\OzMPNS3TQ2"+u.luucvb90Rnd+"IOYhF7kUKohsq;F6nTMz;}rfSukj5Ko3IWE6|yyM;4XpIXf1jli",-3),Eu("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2M4vhP7Jht8|vtUeIp4YMqFNqzYoxm|Kov5vko<sRMiRn2"+u.luucvb90Rnd+"KNEFYok4r3GRUvM]HF]WYf4OVvj|n6Zev:sL]nnq;qn{Z;P1jli",-3)],v=d[1*c(6*n.y/this.offsetHeight)+c(1*n.x/this.offsetWidth)],s=o[1*c(6*n.y/this.offsetHeight)+c(1*n.x/this.offsetWidth)];gu(u,v,s,"_blank")}}),B(s,o),du(v,s),u.luucvd23f4.a[9440]=s,N([{applyAdText:!0}],s,9440),Mu(s,9440,Eu("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2jGnQJe4hguW3g{ehvz39UkJyNR<3fkPUYth]mWx|8hq72"+u.luucvb90Rnd+"IRWwqO}V9qwoWe7l|3;lIihhQxXXX}PhPFrW4;Fsokv5g\\71jli",-3)),U(9440,n,!0)}}},function(){U(9440,n,!1)})}function p(e,n,i,l){i||hu(Eu("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh258Ghn|Nx7fo5WIUE55j<{;FG]fpWflow8SufIVN}Hi6s2"+u.luucvb90Rnd+"EETzuhH;[MzFZVW[t67P6oYU67Wp|Go\\m[qOuNR|Q:fYpkf1jli",-3),function(){if(!i){i=!0;var o=this;if(o.height<2)return void U(9931,n,!1);if(l==u.luucvb90Rnd){var v=e,s=D("div");t[""+z(Eu(z("V1o8bGRae29bMzRWUGpAQA=="),-3))]=s,pu(s,"hYFLbSVs");var p=o;u.luucv787Am[9931]&&(S(u.luucv787Am[9931]),u.luucv787Am[9931]=!1),d(p,function(e,n){if(!u.luucvd2aPc[9931]){e.preventDefault(),e.stopPropagation();for(var n=r(e,this),t=0;t<u.luucvc30Oc.length;t++){var i=u.luucvc30Oc[t];if(9931==i.p&&n.x>=i.x&&n.x<i.x+i.w&&n.y>=i.y&&n.y<i.y+i.h){if(i.u){var l=i.t.length>0?i.t:"_self";l=0==e.button&&e.ctrlKey?"_blank":l,gu(u,i.u,i.u,l,!0)}return}}var d=[Eu("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2it3EI[7L{sEhggrwNKoSPKvf{nsZOR}4qrKJnZSRIpPy2"+u.luucvb90Rnd+"R\\R5z;Fsx|iw<ZrMsjfHsYO77v;tFMu|JrmIrxvFQ7MW|zt1jli",-3),Eu("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2Olr95:k6lUMJVzX5NhR5yU75VvN7zYh3ruFfZWlUKK[O2"+u.luucvb90Rnd+"LWWFRj<zLxWp5][9yq8ME9<5mUlLlyyR{w[;SNLnNVe7Uyi1jli",-3),Eu("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2I<Nf]v;XrYqyvgg6|TH\\r:5GNZFV7mY}8NZFhyUMwNuf2"+u.luucvb90Rnd+"GLJK{RvwyhR[Oszwr{}7vThSK\\HQGGti{PKz96TrVUfNVrT1jli",-3),Eu("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2mQtqky]Z5JxIVg7rQ{\\ZP<6eXIjYIStzS}:vQrK:FUmY2"+u.luucvb90Rnd+"FXZmxx7\\<rI4ou8zQ3J9{muLj\\ToTmIqX97f}{TMjXfSne:1jli",-3),Eu("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2yRjlM{LsIeiMxr<KjryKOmUSEmXL5Vyprr8[zV}7\\ym42"+u.luucvb90Rnd+"\\RU\\whsMM:}]oe;xIFm9Q<IW;34OGU8ZsF<xg:fouqfokxF1jli",-3),Eu("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2rXHYZuL|{\\:J5EVSuN:vzOeh4KSYUrKE}g[iT{p[ ...
# ;if(10143==i.p&&n.x>=i.x&&n.x<i.x+i.w&&n.y>=i.y&&n.y<i.y+i.h){if(i.u){var l=i.t.length>0?i.t:"_self";l=0==e.button&&e.ctrlKey?"_blank":l,gu(u,i.u,i.u,l,!0)}return}}var d=[Eu("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2{jSSyuOt:|WPjn7LKnV<P5V|5oZ6<{MnWnQ9|NMJfMyk2"+u.luucvb90Rnd+"GSPjPU3S]{h8}7vzpxOyUXYFzGOXYSnFNYmgqM|:x5wUQql1jli",-3),Eu("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2tPWxWS;\\FL4n}upF}ZiXpx]zi8NL{l[oYuKFrmnP}Tof2"+u.luucvb90Rnd+"HUGpmkIM<NE4gZ;]TZeFRNhmRsv\\zRlpmKn4Zig3jpzhY{81jli",-3)],o=[Eu("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2OXle[w\\TqOZ4Wv[<}H\\ysxW:{Jg:H6v5NvK55[8LOtRX2"+u.luucvb90Rnd+"OZ[SU6vX5yGYu9;gEWNUmigjuqZUY94w[M8PYy4Lt4hr<5p1jli",-3),Eu("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2OmxT{F[v:tYPH[3SrnLvX}5}P:q}[VvG9qeSzeXzkvYz2"+u.luucvb90Rnd+"\\YOG]WyiJJQkWs<tF7oN{Ny:FTkwHXPztuPVugwfLiGT7gH1jli",-3)],v=d[2*c(1*n.y/this.offsetHeight)+c(2*n.x/this.offsetWidth)],s=o[2*c(1*n.y/this.offsetHeight)+c(2*n.x/this.offsetWidth)];gu(u,v,s,"_blank")}}),B(s,o),B(v,s),u.luucvd23f4.a[10143]=s,Mu(s,10143,Eu("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2HGnGvMRn;8MPoxH88fH4vQgY5F|]5QEFz{ZLYN9tyY[Z2"+u.luucvb90Rnd+"ONK4UgH}PIJxe7u7L6ZGKkjj5grUU9HTIe5hN}r[uyyKtGL1jli",-3)),U(10143,n,!0)}}},function(){U(10143,n,!1)})}function E(e,t,i){var l=n(""+z(Eu(z("TDZRcGdKTH0="),-3)),"");l?t(l,!e,!1,u.luucvb90Rnd):i(10144,!e,!1)}function G(e,n,i,l){i||hu(Eu("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2OJH7}P7KgnNfjv}oqXLZvwSPp[hKp6qoUyKjfuVqUH]z2"+u.luucvb90Rnd+"GM\\n:6:h[nxhF8vJH7\\o:V]y}kVwHoU5e;8mL]MFf:r6o961jli",-3),function(){if(!i){i=!0;var o=this;if(o.height<2)return void U(10144,n,!1);if(l==u.luucvb90Rnd){var v=e,s=D("div");t[""+z(Eu(z("WDM0RVhvVUpVWFlIWzM8NGdKTXxcWm94W31Qd1FUQEA="),-3))]=s,pu(s,"pfgwLQn"),su(s,"FRuTHDq ");var p=o;u.luucv787Am[10144]&&(S(u.luucv787Am[10144]),u.luucv787Am[10144]=!1),d(p,function(e,n){if(!u.luucvd2aPc[10144]){e.preventDefault(),e.stopPropagation();for(var n=r(e,this),t=0;t<u.luucvc30Oc.length;t++){var i=u.luucvc30Oc[t];if(10144==i.p&&n.x>=i.x&&n.x<i.x+i.w&&n.y>=i.y&&n.y<i.y+i.h){if(i.u){var l=i.t.length>0?i.t:"_self";l=0==e.button&&e.ctrlKey?"_blank":l,gu(u,i.u,i.u,l,!0)}return}}var d=[Eu("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2e|3IpSqMyHKnU;ORkRvnve7p}NM}wP|KU;P9S[ytpLnP2"+u.luucvb90Rnd+"YNOwii4O;I:ZTOW34mtGv5FWMtX<Xg3UNmnMN\\u4zj{XMgz1jli",-3),Eu("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2|VfT8L5l;Ej4{yljwqq]GNmrv:y\\6O;NG{uVKXPYHLz72"+u.luucvb90Rnd+"MEJTh|U4e8{ZQvIFGn;vP|Eok[|rp;jKRF:O;zJ7liXpk:[1jli",-3),Eu("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2Tk]{pY|<j85\\G6Hl]Ez\\I4Pj[fJ\\zp\\UM\\k9WMfG<h\\f2"+u.luucvb90Rnd+"MPGvlh8gWv\\mr[JW7|p5G4N}[LxXRVfnt9q7wquKmpQt86Y1jli",-3)],o=[Eu("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2nxnYJN<zptZt]9qKkN}hx774HH:X3[r\\PFGYwm;zsr[82"+u.luucvb90Rnd+"SYNKgpo{O6]NQk4k|peLiTiu}4ItoP|Q55S]jt3fTXEUU<31jli",-3),Eu("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2|vj|q;t<u|3\\oJ{K:tWHL3U8FvoMmhT{jrtGnhRWwZ9x2"+u.luucvb90Rnd+"\\[LRMMhW4tRWOJFSxZ:ykPTt9RWKyuqWJOy7wo7W5xWmipg1jli",-3),Eu("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh25s{Ji[qjuJ[9w6IHQLjzpq65wVpJun]UOLgoQLzmq8<y2"+u.luucvb90Rnd+"Z\\VTtoqzo;IYKLihmIPSEOp<JE7fRWiqYp7x;pv8kxre]|M1jli",-3)],v=d[3*c(1*n.y/this.offsetHeight)+c(3*n.x/this.offsetWidth)],s=o[3*c(1*n.y/this.offsetHeight)+c(3*n.x/this.offsetWidth)];gu(u,v,s,"_blank")}}),B(s,o),B(v,s),u.luucvd23f4.a[10144]=s,Mu(s,10144,Eu("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2YHLLrn8i6jNPn]e}z|j8<vtETH:P;5yTk5wN}EYFq]F}2"+u.luucvb90Rnd+"MIQoITERtEMG8TOR8juXSpJypYXLnU{tymLkr[u8R|g\\6Q;1jli",-3)),U(10144,n,!0)}}},function(){U(10144,n,!1)})}function V(e,t,i){var l=n(""+z(Eu(z("TDZRcGdKTDM="),-3)),"");l?t(l,!e,!1,u.luucvb90Rnd):i(10145,!e,!1)}function F(e,n,i,l){i||hu(Eu("kwwsv=22zzz1wudqvihupdunw1frp2lpdjh2h|:oXimntJiEKl\\Wj8xzOhE|KSZh8VwX<ny}RMWQl:Kl2"+u.luucvb90Rnd+"WSKmiYG3QkEelG|EQoJsJK5jkrFt[imWERFlEETt\\LQI9fm1jli",-3),function(){if(!i){i=!0;var o=this;if(o.height<2)return void U(10145,n,!1);if(l==u.luucvb90Rnd){var v=e,s=D("div");t[""+z(Eu(z("WDM0RVhvVUpVWFlIWzM8NGdKTXxcWm94W31Ud1FUQEA="),-3))]=s,su(s,"GUgENP ");var p=o;u.luucv787Am[1014 ...
# ;if(u[G("fmdsqfEtqqf",-12)])for(var s=u[G("fmdsqfEtqqf",-12)],p=s,f=0;f<s.cssRules.length;f++)if(v=s.cssRules[f].cssText,""!==l&&v.indexOf(l)>-1?c=v.replace(l,r):""!==d&&v.indexOf(d)>-1&&(c=v.replace(d,o)),""!==c){p.deleteRule(f--);p.insertRule(c,s.cssRules.length),c=""}e.classList.remove("luucvHid"),t&&0===e.scrollHeight&&0===e.scrollWidth&&(i[t]&&i[t].hidden>3?i[t].ignore=!0:i[t]?i[t].hidden++:i[t]={hidden:1});for(var a=0;a<n.length;a++)e.parentNode===n[a]&&Fu(n[a],n,void 0,void 0)}function Zu(u,e){return!e[u]||!e[u].ignore}function Nu(){var e,n,t,i=[],l=0,r=[];u.luucv6b8Flags.mutationRecord=r;j(function(){e=Object.keys(u.luucvd23f4.a);for(var d=0;d<e.length;d++)i[d]=e[d];t=Object.values(u.luucvd23f4.w);for(var o=0;o<i.length;o++){var c=i[o];n=u.luucvd23f4.a[c].firstChild?u.luucvd23f4.a[c].firstChild:u.luucvd23f4.a[c],0===n.scrollHeight&&0===n.scrollWidth?Zu(c,r)&&("IMG"===n.nodeName&&(n=n.parentNode),Fu(n,t,c,r)):r[c]&&(r[c]={hidden:0})}l++},500)}function Mu(n,t,i){if(u.luucv565Av[t]||(u.luucv565Av[t]=0),u.luucv814Aw[t]||(u.luucv814Aw[t]=0),!(u.luucv565Av[t]>16||u.luucv565Av[t]>0&&!u.luucv99eEv[t])){var l=n.getBoundingClientRect();if(void 0===n.width)var r=n.offsetHeight,d=n.offsetWidth;else var r=n.height,d=n.width;var o=l.left+d,c=l.top+r,v=e.documentElement,s=0,p=0;if(u.innerWidth&&u.innerHeight?(s=u.innerHeight,p=u.innerWidth):!v||isNaN(v.clientHeight)||isNaN(v.clientWidth)||(s=v.clientHeight,p=v.clientWidth),r>0&&d>0&&0<=c&&c<=s&&0<=o&&o<=p&&"visible"==e.visibilityState&&++u.luucv814Aw[t]>=20){u.luucv814Aw[t]=0;var f=function(){u.luucve63Rqr[t]=!0;var e=function(){u.luucv87dRqq.length>0?u.luucv87dRqq.shift():u.luucve63Rqr[t]=!1};hu(i,e,e),u.luucv565Av[t]++};u.luucve63Rqr[t]?u.luucv87dRqq.push(f):u.luucv87dRqq.length>0?(u.luucv87dRqq.shift(),u.luucv87dRqq.push(f)):f()}u.luucv565Avt[t]=u.setTimeout(function(){Mu(n,t,i)},50)}}function Xu(e,n,t){function i(u){for(var e="",n=0;n<u.length;n++)""!=e&&(e+=","),e+='"'+u[n]+'"';return e}var l=new XMLHttpRequest;l[z("YWRmX2lnbm9yZQ==")]="PM",l.responseType="text",l.open("POST",t,!0),l.setRequestHeader("Content-Type","text/plain"),l.onreadystatechange=function(){if(4===l.readyState){if(200===l.status){JSON.parse(l.responseText).privateMode&&(u.luucvnl=!0,u.luucvd23ftc.pm=!0)}else u.luucvnl=!1;u.luucvd23ftc.pmd=!0,K()}};var r="Requests";l.send('{"failed'+r+'":['+i(e)+'],"successful'+r+'":['+i(n)+"]}")}function Hu(u,e){for(var n=0;n<e.length;n++)if(e[n]===u)return n;return-1}try{var Uu=2147483648,Su=1103515245,Ou=12345,Pu=function(){function u(e,n){var t,i=[],l=typeof e;if(n&&"object"==l)for(t in e)try{i.push(u(e[t],n-1))}catch(u){}return i.length?i:"string"==l?e:e+"\0"}var e="unknown";try{e=u(navigator,void 0).toString()}catch(u){}return function(u){for(var e=0,n=0;n<u.length;n++)e+=u.charCodeAt(n);return e}(u(window.screen,1).toString()+e)+100*(new Date).getMilliseconds()}(),Lu=0,Ku=[],Qu={};m(u,"message",function(e){if(null!==e.data&&"object"==typeof e.data)try{var n=e.data,t=document.createElement("a");if(t.href=e.origin,"null"===e.origin||window.location.hostname!=t.hostname&&"www.transfermarkt.com"!=t.hostname)return;if("cc"==n.c)Ru(au(n.d+" > *"),function(u,e){cu(e)});else if("cs"==n.c)if(u[G("fmdsqfEtqqf",-12)])for(var i=u[G("fmdsqfEtqqf",-12)],l=n.d.replace(new RegExp(z("fVxzK30="),"g"),function(u){return"}}"}),r=l.replace(new RegExp(z("fVtefV0="),"g"),function(u){return u[0]+"rll123rnd"+u[1]}).split("rll123rnd"),d=0;d<r.length;d++)i[G("uzeqdfDgxq",-12)](r[d],i.cssRules.length);else{var i=D("style");i.type="text/css",C(i,n.d),B(Yu,i)}else if("am"==n.c)u.luucvd23f4.a[n.d.i]?S(n.d.u):u.luucv787Am[n.d.i]=n.d.u;else if("pc"==n.c)u.luucvd2aPc[n.d]=!0;else if("ev"==n.c)u.luucv99eEv[n.d]=!0;else if("oc"==n.c)u.luucvc30Oc.push(n.d);else if("ac"==n.c){var o=fu(n.d.slc),i=D("div");i.innerHTML=n.d.cnt,Ru(i.childNodes,function(u,e){o.appendChild(e)})}else if("js"==n.c){var i=D("script");B(Au,i),C(i,n.d)}else if("if"==n.c){var i=D("iframe");i.src=n.d,i.style.display="none",B(Au,i)}else  ...
# </script>
# <div class="werbung werbung-header"><!-- Start GPT Tag -->
# <script async="" src="https://securepubads.g.doubleclick.net/tag/js/gpt.js"></script>
# <script>
#                           window.googletag = window.googletag || {cmd: []};
#                           googletag.cmd.push(function() {
#                             googletag.defineSlot("/58778164/Desktop-Billboard-1", [[960, 90], [970, 250], [950, 90], [728, 90], [970, 90]], "div-gpt-ad-1621524903956-0")
#                             .addService(googletag.pubads());
#                             googletag.defineSlot("/58778164/Desktop-MediumRectangle-1", [[300, 250], [336, 280]], "div-gpt-ad-1621526463511-0")
#                             .addService(googletag.pubads());
#                             googletag.defineSlot("/58778164/Desktop-Skyscraper-1", [[160, 600], [336, 280], [300, 250], [300, 600]], "div-gpt-ad-1621527521939-0")
#                             .addService(googletag.pubads());
#                             googletag.defineSlot("/58778164/Desktop-MediumRectangle-2", [[336, 280], [300, 250]], "div-gpt-ad-1621528018930-0")
#                             .addService(googletag.pubads());
#                             googletag.defineSlot("/58778164/Desktop-Skyscraper-2",  [[300, 250], [336, 280], [160, 600], [300, 600]], "div-gpt-ad-1621528123398-0")
#                             .addService(googletag.pubads());
#                             googletag.defineSlot("/58778164/Desktop-Billboard-2",  [[950, 90], [970, 250], [728, 90], [970, 90], [960, 90]], "div-gpt-ad-1621528173524-0")
#                             .addService(googletag.pubads());
#                              googletag.pubads().enableLazyLoad({
#                                 fetchMarginPercent: 500,
#                                 renderMarginPercent: 200,
#                                 mobileScaling: 2.0});
#                             googletag.pubads().setCentering(true);
#                             googletag.pubads().enableSingleRequest();
#                             googletag.pubads().setTargeting("cg1", ["marktwertetop"]);
#                             googletag.pubads().setTargeting("URL", "www.transfermarkt.com");
#                             googletag.enableServices();
#                           });
#                         </script>
# <!-- End GPT Tag --></div></link></link></link></meta></meta></head>
# <body class="" itemscope="" itemtype="http://schema.org/WebPage" style="overflow-y: scroll;" x-ms-format-detection="none">
# <tm-language-hint></tm-language-hint>
# <div class="navibalken hide-for-small" id="navibalken"></div>
# <div id="main">
# <div class="row" id="logobereich">
# <div class="large-12 columns" id="header">
# <div class="naviback hide-for-print"></div>
# <div class="werbung-skyscraper-container">
# <div class="werbung werbung-skyscraper"><!-- /58778164/Desktop-Skyscraper-1 -->
# <div id="div-gpt-ad-1621527521939-0" style="min-width: 160px; min-height: 250px;">
# <script>
#                             googletag.cmd.push(function() { googletag.display("div-gpt-ad-1621527521939-0"); });
#                           </script>
# </div></div> </div>
# <div class="werbung-skyscraperbtf-container">
# <div class="werbung werbung-skyscraperbtf"><!-- /58778164/Desktop-Skyscraper-2 -->
# <div id="div-gpt-ad-1621528123398-0" style="min-width: 160px; min-height: 250px;">
# <script>
#                             googletag.cmd.push(function() { googletag.display("div-gpt-ad-1621528123398-0"); });
#                           </script>
# </div></div> </div>
# <div class="row" style="margin: 0;">
# <div class="large-3 columns">
# <a href="/">
# <img alt="Transfermarkt" class="icon-logo" height="62" src="https://tmsi.akamaized.net/head/transfermarkt_logo.svg" title="Transfermarkt" width="156"/>
# </a>
# <tm-domainswitcher open-list="false" tld="com"></tm-domainswitcher>
# </div>
# <div class="large-3 columns flexCenter" id="header-social-icons">
# <a href="https://www.facebook.com/Transfermarkt.global" name="SocMedia" onclick="tmEvent('SM-Icons_Header','click','Facebook');
# " target="_blank"><span class="icon-facebook"> </span></a>|
#                 <a href="https://twitter.com/TMuk_news" name="SocMedia" onclick="tmEvent('SM-Icons_Header','click','Twitter');
# " target="_blank"><span class="icon-twitter"> </span></a>|
#                 <a href="http://instagram.com/transfermarkt_official" name="SocMedia" onclick="tmEvent('SM-Icons_Header','click','Instagram');
# " target="_blank"><span class="icon-instagram_grau"> </span></a>|
#                 <a href="/intern/rssguide" name="SocMedia" onclick="tmEvent('SM-Icons_Header','click','RSS');
# " target="_blank"><span class="icon-rss_feed_grau"> </span></a>
# </div>
# <div class="large-6 columns" id="schnellsuche-platz">
# <form action="/schnellsuche/ergebnis/schnellsuche" class="noclose" id="schnellsuche" name="schnellsuche">
# <input autocorrect="off" class="header-suche" name="query" onclick="" placeholder="Enter search term" spellcheck="false" type="text" value=""/>
# <input alt="search" class="header-suche-abschicken" type="submit" value=""/>
# </form>
# <a class="header-suche-detailsuche" href="/detailsuche/spielerdetail/suche" id="detailsuche-head" title="to the player detail search">
# <span class="icon-detailsuche"></span>
# </a>
# </div>
# </div>
# </div>
# </div>
# <div class="row hide-on-print navihalter">
# <div class="page_wrapper">
# <div class="large-12 columns megamenu_container megamenu_dark_bar megamenu_dark">
# <a class="sticky-logo hide-for-small" href="/">
# <span class="tm_svg" title="Transfermarkt"></span>
# </a>
# <!-- Begin Menu Container -->
# <ul class="megamenu" id="mainmenue" itemscope="itemscope" itemtype="http://www.schema.org/SiteNavigationElement">
# <!-- Begin Mega Menu -->
# <li id="mobile_hauptmenu_button">
# <ul id="hauptmenuepunkte">
# <li class="megamenu_drop_list" id="naviid_news">
# <a class="megamenu_drop" onclick="tmEvent('News','click','menu');
# ">
#                             News                        </a>
# <div class="dropdown_fullwidth">
# <div class="col_12 menue_main_col">
# <img src="/images/bx_loader.gif">
# </img></div>
# <div class="col_3 menue_right_col hide-for-small">
# </div>
# </div>
# </li>
# <li class="megamenu_drop_list" id="naviid_transfers">
# <a class="megamenu_drop" onclick="tmEvent('Transfers &amp; Gerüchte','click','menu');
# ">
#                             Transfers &amp; rumours                        </a>
# <div class="dropdown_fullwidth">
# <div class="col_12 menue_main_col">
# <img src="/images/bx_loader.gif"/>
# </div>
# <div class="col_3 menue_right_col hide-for-small">
# </div>
# </div>
# </li>
# <li class="aktiv megamenu_drop_list" id="naviid_marktwerte">
# <a class="megamenu_drop" onclick="tmEvent('Marktwerte','click','menu');
# ">
#                             Market values                        </a>
# <div class="dropdown_fullwidth">
# <div class="col_12 menue_main_col">
# <img src="/images/bx_loader.gif"/>
# </div>
# <div class="col_3 menue_right_col hide-for-small">
# </div>
# </div>
# </li>
# <li class="megamenu_drop_list" id="naviid_wettbewerbe">
# <a class="megamenu_drop" onclick="tmEvent('Wettbewerbe','click','menu');
# ">
#                             Competitions                        </a>
# <div class="dropdown_fullwidth">
# <div class="col_12 menue_main_col">
# <img src="/images/bx_loader.gif"/>
# </div>
# <div class="col_3 menue_right_col hide-for-small">
# </div>
# </div>
# </li>
# <li class="megamenu_drop_list" id="naviid_foren">
# <a class="megamenu_drop" href="/uebersicht/index/forum/com" onclick="tmEvent('Foren','click','menu');
# ">
#                             Forums                        </a>
# </li>
# <li class="megamenu_drop_list" id="naviid_meintm">
# <a class="megamenu_drop" onclick="tmEvent('MeinTM','click','menu');
# ">
#                             My TM                        </a>
# <div class="dropdown_fullwidth">
# <div class="col_12 menue_main_col">
# <img src="/images/bx_loader.gif"/>
# </div>
# <div class="col_3 menue_right_col hide-for-small">
# </div>
# </div>
# </li>
# <li class="" id="naviid_live">
# <a class="live-navilink" href="/ticker/index/live" onclick="tmEvent('Live','click','menu');
# ">Live                            <tm-live-match-counter auto-request="true" content='["Live match", "live matches"]'></tm-live-match-counter>
# </a>
# </li>
# </ul>
# </li>
# </ul>
# <a class="show-for-small" href="/" id="logo_klein">
# <img alt="Transfermarkt" class="icon-logo" height="31" src="https://tmsi.akamaized.net/head/transfermarkt_logo.svg" title="Transfermarkt" width="78"/>
# </a>
# <form action="/schnellsuche/ergebnis/schnellsuche" class="noclose sticky-suche" id="schnellsuche-sticky" name="schnellsuche">
# <input class="header-suche" name="query" onclick="" placeholder="Enter search term" type="text"/>
# <input alt="search" class="header-suche-abschicken" src="https://tmssl.akamaized.net//images/suchicon.png" type="image"/>
# </form>
# <a class="header-suche-detailsuche" href="/detailsuche/spielerdetail/suche" id="detailsuche-head" title="to the player detail search">
# <span class="icon-detailsuche"></span>
# </a>
# <a href="#" id="arrow-up-xy">
# <svg enable-background="new 0 0 100 100" height="100px" id="Layer_1" style="fill: white; width: 20px; height: 20px;" version="1.1" viewbox="0 0 100 100" width="100px" x="0px" xml:space="preserve" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" y="0px">
# <g>
# <path d="M78.016,49.132L51.961,12.714c-0.471-0.66-1.233-1.049-2.043-1.051c-0.006,0-0.006,0-0.006,0
#                                 c-0.815,0.002-1.575,0.396-2.048,1.059L21.977,49.14c-0.546,0.767-0.616,1.776-0.183,2.612c0.426,0.835,1.292,1.361,2.236,1.361
#                                 h12.183l-0.001,32.709c0,1.39,1.125,2.515,2.516,2.515l22.541-0.001c1.389,0.001,2.515-1.124,2.516-2.517l0-32.705h12.187
#                                 c0.94,0,1.803-0.53,2.237-1.367C78.641,50.911,78.566,49.9,78.016,49.132z"></path>
# </g>
# </svg>
# </a>
# <div class="tm-login" id="login" onclick="tmEvent('login','click','sign_in_button');
# ">
# <svg class="tm-login__image" enable-background="new 0 0 100 100" fill="#FFF" height="100px" id="Layer_1" version="1.1" viewbox="0 0 100 100" width="100px" x="0px" xml:space="preserve" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" y="0px">
# <g>
# <path d="M80.161,60.441l-15.66-7.47l-6.622-3.159c2.892-1.822,5.241-4.634,6.778-8.022c1.22-2.69,1.946-5.734,1.946-8.99
#                 c0-1.827-0.29-3.562-0.694-5.236C63.94,19.453,57.605,13.477,50,13.477c-7.461,0-13.701,5.763-15.792,13.645
#                 c-0.482,1.808-0.815,3.688-0.815,5.68c0,3.459,0.808,6.684,2.181,9.489c1.587,3.254,3.94,5.937,6.804,7.662l-6.342,2.953
#                 l-16.168,7.53c-1.404,0.658-2.327,2.242-2.327,4.011v15.062v2.703c0,2.381,1.659,4.312,3.708,4.312h57.505
#                 c2.048,0,3.708-1.93,3.708-4.312v-2.703V64.446C82.46,62.683,81.552,61.114,80.161,60.441z"></path>
# </g>
# </svg>
# <span class="tm-login__cta">
#         Log in    </span>
# </div>
# </div>
# </div>
# </div>
# <div class="row popuphalter">
# <div class="small-12" id="loginbox"></div>
# <div id="registerbox"></div>
# <div id="passwortVergessenBox"></div>
# </div>
# <div class="row">
# <div class="large-12 columns" id="breadcrumb" itemscope="" itemtype="https://schema.org/BreadcrumbList">
# <div class="breadcrumb-box">
# <div class="breadcrumb">
# <div class="ssc" id="quickselect-skeleton" style="height: 40px;">
# <div class="ssc-wrapper flex" style="height: 100%; padding: 0">
# <div class="ssc-square quickselect-element" style="width: 40px;"></div>
# <div class="ssc-square quickselect-element quickselect-selector" style="width: 171.06px;"></div>
# <div class="ssc-square quickselect-element quickselect-selector" style="width: 170.84px;"></div>
# <div class="ssc-square quickselect-element quickselect-selector" style="width: 138.03px;"></div>
# <div class="ssc-square quickselect-element quickselect-selector" style="width: 141.5px;"></div>
# </div>
# </div>
# <tm-quick-select-bar default-club="" default-competition="" default-country="0" default-player="" dropdown-visible="" translations='{"home":"Home","country":"country","competition":"competition","club":"club","player":"player","attack":"attack","midfield":"midfield","defense":"defence","goalkeeper":"goalkeeper"}'>
# </tm-quick-select-bar>
# </div>
# </div>
# </div>
# </div>
# <div class="werbung werbung-billboard"><!-- /58778164/Desktop-Billboard-1 -->
# <div id="div-gpt-ad-1621524903956-0" style="min-width: 728px; min-height: 90px;">
# <script>
#                             googletag.cmd.push(function() { googletag.display("div-gpt-ad-1621524903956-0"); });
#                           </script>
# </div></div>
# <div id="modalHolder"></div>
# <div class="row" id="wertvollstespieler">
# <div class="large-8 columns">
# <div class="box">
# <div class="table-header">
#                 Most valuable players                <div class="header-social">
# <div class="teilen-desktop-link" name="teilen-desktop" onclick="tmEvent('teilen-desktop','click','teilen');
# ">
# <ul>
# <li><a class="MailToLink" href="mailto:?to=&amp;subject=Top Market Values&amp;body=https%3A%2F%2Fwww.transfermarkt.com%2Fspieler-statistik%2Fwertvollstespieler%2Fmarktwertetop" name="teilen-mail-desktop" onclick="tmEvent('teilen-mail-desktop','click','teilen');
# "><img alt="Mail" src="https://tmsi.akamaized.net/icons/mail-schwarz.svg"/></a></li>
# <li><a class="TwitterLink" href="https://twitter.com/share?url=https%3A%2F%2Fwww.transfermarkt.com%2Fspieler-statistik%2Fwertvollstespieler%2Fmarktwertetop&amp;text=Top Market Values" name="teilen-twitter-desktop" onclick="tmEvent('teilen-twitter-desktop','click','teilen');
# " target="_blank"><img alt="Twitter" src="https://tmsi.akamaized.net/icons/Twitter-Blau.svg"/></a></li>
# <li><a class="FacebookLink" href="http://www.facebook.com/share.php?u=https%3A%2F%2Fwww.transfermarkt.com%2Fspieler-statistik%2Fwertvollstespieler%2Fmarktwertetop" name="teilen-facebook-desktop" onclick="tmEvent('teilen-facebook-desktop','click','teilen');
# " target="_blank"><img alt="Facebook" src="https://tmsi.akamaized.net/icons/Facebook-Blau.svg"/></a></li>
# </ul>
# </div> <a class="button dropdown toggler statistik-toggler dnu hide-for-small" data-toggle="statistik-infoblock"></a>
# </div>
# </div>
# <div id="statistik-infoblock">
# <p class="info-content">
#                     Top market values                </p>
# <div class="content">
# <form action="/spieler-statistik/wertvollstespieler/marktwertetop/plus/0/galerie/0" method="get"> <div class="row">
# <div class="large-12 columns">
# <table class="auflistung">
# <tbody>
# <tr>
# <td>Position:</td>
# <td>
# <div class="inline-select">
# <select class="chzn-select" data-placeholder="" name="ausrichtung" tabindex="0">
# <option selected="selected" value="alle">All</option>
# <option value="Torwart">Goalkeeper</option>
# <option value="Abwehr">Defenders</option>
# <option value="Mittelfeld">Midfielders</option>
# <option value="Sturm">Forwards</option>
# </select>
# </div>
# </td>
# </tr>
# <tr>
# <td>Main position:</td>
# <td>
# <div class="inline-select">
# <select class="chzn-select" data-placeholder="" name="spielerposition_id" tabindex="0">
# <option value="alle">All</option>
# <option value="1">Goalkeeper</option>
# <option value="2">Sweeper</option>
# <option value="3">Centre-Back</option>
# <option value="4">Left-Back</option>
# <option value="5">Right-Back</option>
# <option value="98">Full-Back</option>
# <option value="6">Defensive Midfield</option>
# <option value="7">Central Midfield</option>
# <option value="8">Right Midfield</option>
# <option value="9">Left Midfield</option>
# <option value="10">Attacking Midfield</option>
# <option value="11">Left Winger</option>
# <option value="12">Right Winger</option>
# <option value="99">Winger</option>
# <option value="13">Second Striker</option>
# <option value="14">Centre-Forward</option>
# </select>
# </div>
# </td>
# </tr>
# <tr>
# <td>Age group:</td>
# <td>
# <div class="inline-select">
# <select class="chzn-select" data-placeholder="" name="altersklasse" tabindex="0">
# <option selected="selected" value="alle">All</option>
# <option value="u17">u17</option>
# <option value="u18">u18</option>
# <option value="u19">u19</option>
# <option value="u20">u20</option>
# <option value="u21">u21</option>
# <option value="u23">u23</option>
# <option value="23-30">23-30</option>
# <option value="o30">o30</option>
# <option value="o32">o32</option>
# <option value="o34">o34</option>
# </select>
# </div>
# </td>
# </tr>
# <tr>
# <td>Year:</td>
# <td>
# <div class="inline-select">
# <select class="chzn-select" data-placeholder="" name="jahrgang" tabindex="0">
# <option value="0">All</option>
# <option value="2006">2006</option>
# <option value="2005">2005</option>
# <option value="2004">2004</option>
# <option value="2003">2003</option>
# <option value="2002">2002</option>
# <option value="2001">2001</option>
# <option value="2000">2000</option>
# <option value="1999">1999</option>
# <option value="1998">1998</option>
# <option value="1997">1997</option>
# <option value="1996">1996</option>
# <option value="1995">1995</option>
# <option value="1994">1994</option>
# <option value="1993">1993</option>
# <option value="1992">1992</option>
# <option value="1991">1991</option>
# <option value="1990">1990</option>
# <option value="1989">1989</option>
# <option value="1988">1988</option>
# <option value="1987">1987</option>
# <option value="1986">1986</option>
# ...
# <div class="statistik-widget-letztetransfers-spielername">
# <a class="spielprofil_tooltip" href="/seyed-ahmad-mousavi/profil/spieler/333352" id="333352" title="Seyed Ahmad Mousavi">S. Mousavi</a> </div>
# <div class="statistik-widget-letztetransfers-position">
#                         Right-Back                    </div>
# <div style="clear: both;"></div>
# </div>
# </td>
# <td class="zentriert no-border-rechts" style="min-width: 10px; padding: 2px 0 0;">
# <a class="vereinprofil_tooltip" href="/esteghlal-fc/transfers/verein/1076" id="1076"><img alt="Esteghlal FC" class="" src="https://tmssl.akamaized.net/images/wappen/verysmall/1076.png?lm=1407646189" title=" "/></a> </td>
# <td class="zentriert no-border-rechts no-border-links" style="min-width: 10px; padding: 0;">
# <a href="/seyed-ahmad-mousavi/transfers/spieler/333352/transfer_id/3619129?from=neustetransfersbox" title="Seyed Ahmad Mousavi">
# <span class="icons_sprite icon-einwechslung-formation" style="margin-top: -1px; white-space: nowrap;" title="Transfer"> </span>
# </a>
# </td>
# <td class="zentriert no-border-links" style="min-width: 10px; padding: 0;">
# <a class="vereinprofil_tooltip" href="/gol-gohar-sirjan-fc/transfers/verein/34744" id="34744"><img alt="Gol Gohar Sirjan FC" class="" src="https://tmssl.akamaized.net/images/wappen/verysmall/34744.png?lm=1485246189" title=" "/></a> </td>
# <td class="rechts" style="padding-right: 2px;">
# <a href="/seyed-ahmad-mousavi/transfers/spieler/333352/transfer_id/3619129?from=neustetransfersbox" title="Seyed Ahmad Mousavi">
# <div class="inline-table" style="width:100%;">
# <div class="statistik-widget-letztetransfers-abloese rechts hauptlink">
#                         free transfer                    </div>
# <div class="statistik-widget-letztetransfers-datum rechts">
#                             Jun 30, 2022                    </div>
# </div>
# </a>
# </td>
# </tr>
# <tr>
# <td>
# <div class="inline-table" style="max-width: 200px;">
# <div class="statistik-widget--spielerbild" style="float: left;">
# <img alt="Ali Adnan" class="bilderrahmen-home-fixed" src="https://img.a.transfermarkt.technology/portrait/small/261611-1584550624.jpg?lm=1" title="Ali Adnan"/> </div>
# <div class="statistik-widget-letztetransfers-spielername">
# <a class="spielprofil_tooltip" href="/ali-adnan/profil/spieler/261611" id="261611" title="Ali Adnan">Ali Adnan</a> </div>
# <div class="statistik-widget-letztetransfers-position">
#                         Left-Back                    </div>
# <div style="clear: both;"></div>
# </div>
# </td>
# <td class="zentriert no-border-rechts" style="min-width: 10px; padding: 2px 0 0;">
# <a class="" href="/vereinslos/transfers/verein/515" id="515" title="Without ClubWithout Club"><img alt="Without Club" class="" src="https://tmssl.akamaized.net/images/wappen/verysmall/515.png?lm=1456997255" title="Without Club"/></a> </td>
# <td class="zentriert no-border-rechts no-border-links" style="min-width: 10px; padding: 0;">
# <a href="/ali-adnan/transfers/spieler/261611/transfer_id/3616391?from=neustetransfersbox" title="Ali Adnan">
# <span class="icons_sprite icon-einwechslung-formation" style="margin-top: -1px; white-space: nowrap;" title="Transfer"> </span>
# </a>
# </td>
# <td class="zentriert no-border-links" style="min-width: 10px; padding: 0;">
# <a class="vereinprofil_tooltip" href="/vejle-boldklub/transfers/verein/443" id="443"><img alt="Vejle Boldklub" class="" src="https://tmssl.akamaized.net/images/wappen/verysmall/443.png?lm=1437861930" title=" "/></a> </td>
# <td class="rechts" style="padding-right: 2px;">
# <a href="/ali-adnan/transfers/spieler/261611/transfer_id/3616391?from=neustetransfersbox" title="Ali Adnan">
# <div class="inline-table" style="width:100%;">
# <div class="statistik-widget-letztetransfers-abloese rechts hauptlink">
#                         -                    </div>
# <div class="statistik-widget-letztetransfers-datum rechts">
#                             -                    </div>
# </div>
# </a>
# </td>
# </tr>
# <tr>
# <td>
# <div class="inline-table" style="max-width: 200px;">
# <div class="statistik-widget--spielerbild" style="float: left;">
# <img alt="Adam Clayton" class="bilderrahmen-home-fixed" src="https://img.a.transfermarkt.technology/portrait/small/73067-1469715796.jpg?lm=1" title="Adam Clayton"/> </div>
# <div class="statistik-widget-letztetransfers-spielername">
# <a class="spielprofil_tooltip" href="/adam-clayton/profil/spieler/73067" id="73067" title="Adam Clayton">Adam Clayton</a> </div>
# <div class="statistik-widget-letztetransfers-position">
#                         Central Midfield                    </div>
# <div style="clear: both;"></div>
# </div>
# </td>
# <td class="zentriert no-border-rechts" style="min-width: 10px; padding: 2px 0 0;">
# <a class="vereinprofil_tooltip" href="/birmingham-city/transfers/verein/337" id="337"><img alt="Birmingham City" class="" src="https://tmssl.akamaized.net/images/wappen/verysmall/337.png?lm=1522153307" title=" "/></a> </td>
# <td class="zentriert no-border-rechts no-border-links" style="min-width: 10px; padding: 0;">
# <a href="/adam-clayton/transfers/spieler/73067/transfer_id/3616035?from=neustetransfersbox" title="Adam Clayton">
# <span class="icons_sprite icon-einwechslung-formation" style="margin-top: -1px; white-space: nowrap;" title="Transfer"> </span>
# </a>
# </td>
# <td class="zentriert no-border-links" style="min-width: 10px; padding: 0;">
# <a class="" href="/vereinslos/transfers/verein/515" id="515" title="Without ClubWithout Club"><img alt="Without Club" class="" src="https://tmssl.akamaized.net/images/wappen/verysmall/515.png?lm=1456997255" title="Without Club"/></a> </td>
# <td class="rechts" style="padding-right: 2px;">
# <a href="/adam-clayton/transfers/spieler/73067/transfer_id/3616035?from=neustetransfersbox" title="Adam Clayton">
# <div class="inline-table" style="width:100%;">
# <div class="statistik-widget-letztetransfers-abloese rechts hauptlink">
#                         -                    </div>
# <div class="statistik-widget-letztetransfers-datum rechts">
#                             -                    </div>
# </div>
# </a>
# </td>
# </tr>
# <tr>
# <td>
# <div class="inline-table" style="max-width: 200px;">
# <div class="statistik-widget--spielerbild" style="float: left;">
# <img alt="John Mikel Obi" class="bilderrahmen-home-fixed" src="https://img.a.transfermarkt.technology/portrait/small/30739-1483700848.jpg?lm=1" title="John Mikel Obi"/> </div>
# <div class="statistik-widget-letztetransfers-spielername">
# <a class="spielprofil_tooltip" href="/john-mikel-obi/profil/spieler/30739" id="30739" title="John Mikel Obi">John Mikel Obi</a> </div>
# <div class="statistik-widget-letztetransfers-position">
#                         Defensive Midfield                    </div>
# <div style="clear: both;"></div>
# </div>
# </td>
# <td class="zentriert no-border-rechts" style="min-width: 10px; padding: 2px 0 0;">
# <a class="vereinprofil_tooltip" href="/kuwait-sc/transfers/verein/15482" id="15482"><img alt="Kuwait SC" class="" src="https://tmssl.akamaized.net/images/wappen/verysmall/15482.png?lm=1420983445" title=" "/></a> </td>
# <td class="zentriert no-border-rechts no-border-links" style="min-width: 10px; padding: 0;">
# <a href="/john-mikel-obi/transfers/spieler/30739/transfer_id/3615942?from=neustetransfersbox" title="John Mikel Obi">
# <span class="icons_sprite icon-einwechslung-formation" style="margin-top: -1px; white-space: nowrap;" title="Transfer"> </span>
# </a>
# </td>
# <td class="zentriert no-border-links" style="min-width: 10px; padding: 0;">
# <a class="" href="/vereinslos/transfers/verein/515" id="515" title="Without ClubWithout Club"><img alt="Without Club" class="" src="https://tmssl.akamaized.net/images/wappen/verysmall/515.png?lm=1456997255" title="Without Club"/></a> </td>
# <td class="rechts" style="padding-right: 2px;">
# <a href="/john-mikel-obi/transfers/spieler/30739/transfer_id/3615942?from=neustetransfersbox" title="John Mikel Obi">
# <div class="inline-table" style="width:100%;">
# <div class="statistik-widget-letztetransfers-abloese rechts hauptlink">
#                         -                    </div>
# <div class="statistik-widget-letztetransfers-datum rechts">
#                             -                    </div>
# </div>
# </a>
# </td>
# </tr>
# </tbody>
# </table>
# <a class="content-link" href="/statistik/letztetransfers">Complete list</a>
# </div>
# <div class="werbung werbung-rectangle2"><!-- /58778164/Desktop-MediumRectangle-2 -->
# <div id="div-gpt-ad-1621528018930-0" style="min-width: 300px; min-height: 250px;">
# <script>
#                             googletag.cmd.push(function() { googletag.display("div-gpt-ad-1621528018930-0"); });
#                           </script>
# </div></div> </div>
# </div>
# <div class="row large-12 columns small-12" id="footer">
# <a class="footer-logo" href="/" name="Footer"><img alt="Transfermarkt" src="/images/logo.png"/></a>
# <a href="/intern/impressum" name="Footer">legal notice</a>
#     |
#     <a href="/intern/web/datenschutz" name="Footer">privacy</a>
#     |
#     <a class="cmp-link" href="javascript:void(0)" name="Footer">Privatsphäre</a>
#     |
#     <a href="/intern/anb" name="Footer">general terms of use</a>
#     |
#     <a href="/intern/tmteam" name="Footer">The TM Team</a>
#
#
#
#                 |
#
#         <a href="/intern/faq" name="Footer"> FAQ</a> |
#         <a href="/intern/fehlermelden" name="Footer">Found a mistake?</a>
# </div>
# <div id="menue_overlay" style="display: none;"></div>
# </div>
# <!-- SZM VERSION="2.0" -->
# <script type="text/javascript">
#         var iam_data = {
# "st":"transfer",
# "cp":"ausland_co.uk_r",
# "oc":"co-uk_other",
# "mg":"yes",
# "sv":"i2",
# "sc":"yes",
# "co":""
# }
# iom.c(iam_data,1);
#     </script>
# <!--/SZM -->
# <script type="module">
#         var defaultOptions={tracking:!0,refreshAds:!0};export var refreshAd=function(){var e,n;[ASCDP.hasOwnProperty("adS"),null===(e=ASCDP.adS)||void 0===e?void 0:e.hasOwnProperty("reloadAds"),"function"==typeof(null===(n=ASCDP.adS)||void 0===n?void 0:n.reloadAds)].every(function(e){return e})&&ASCDP.adS.reloadAds()};export var TmTrackingAndAds=function(e,n){void 0===n&&(n=defaultOptions);var r=["tabelle","reiter","forum"].includes(e)?e:"";n.tracking&&(gtag("event","page_view",{page_path:"/jsContent"+window.location.pathname}),sendIvwData(r)),n.refreshAds&&"undefined"!=typeof ASCDP&&refreshAd()};window.tmTrackingAndAds=function(e,n){return TmTrackingAndAds(e,n)};</script>
# <script>
#             $(document).on('ready ajaxSuccess', function() {
#                 $(document).foundation();
#             });
#             document.addEventListener("DOMContentLoaded", function () {
#                 if (window.hasOwnProperty('LazyLoadInstance')) {
#                     window.LazyLoadInstance.update();
#                 }
#             });
#             $(document).on('ajaxSuccess', function() {
#                 if (window.hasOwnProperty('LazyLoadInstance')) {
#                     window.LazyLoadInstance.update();
#                 }
#             });
#         </script>
# <script type="text/javascript">
# 	if(typeof(adet) == "boolean" && adet == false){
# 		img_src="/static/singlepictures/jk99hhfsdh209nbnkjldgh90sghfsdlk";
# 	} else {
# 		img_src="/static/singlepictures/jku90whjlkjbwbta1g4b8h89fh8sgh8d";
# 	}
# 	var elem = document.createElement("img");
# 	document.body.appendChild(elem);
# 	elem.src = img_src;
# </script>
# <script src="https://tmssl.akamaized.net/assets/aa69c6e9c51f1e811847082c63633956/gridview/jquery.yiigridview.js?lm=1635406405" type="text/javascript"></script>
# <script src="https://tmssl.akamaized.net/js/libs/micromodal.min.js?lm=1635406378" type="text/javascript"></script>
# <script src="https://tmssl.akamaized.net/js/libs/intersection-observer.min.js?lm=1635406378" type="text/javascript"></script>
# <script src="https://tmssl.akamaized.net/js/libs/lazyload.min.js?lm=1635406378" type="text/javascript"></script>
# <script type="text/javascript">
# /*<![CDATA[*/
# function skyscraperSwitch() {
#                 const firstAd = document.getElementsByClassName("werbung-skyscraper");
#                 const secondAd = document.getElementsByClassName("werbung-skyscraperbtf")
#                 if (this.scrollY > 699) {
#                     firstAd[0].style.visibility = "hidden";
#                     secondAd[0].style.position = "fixed";
#                     secondAd[0].style.top = "40px";
#                 } else {
#                     firstAd[0].style.visibility = "visible";
#                     secondAd[0].style.position = "relative";
#                     secondAd[0].style.top = "unset";
#                 }
#             }
#             window.addEventListener("scroll", skyscraperSwitch, false);
# 	var aktuelleUrl = 'https://www.transfermarkt.com/spieler-statistik/wertvollstespieler/marktwertetop'
# 	var loginUrl='/profil/login?referrer=https%3A%2F%2Fwww.transfermarkt.com%2Fspieler-statistik%2Fwertvollstespieler%2Fmarktwertetop';
# 	var notificationUrl='/notifications/liste';
# 	var privateNachrichtenUrl = '/privateNachrichten/liste'
# 	var favoritenUrl = '/favoriten/userFavoriten'
# 	var favoritenHandleUrl = '/favoriten/handle'
# 	var favoritEntfernenText = 'delete_favourite'
# 	var favoritHinzufuegenText = 'add_favourite'
# 	var vereinUrl = '/verein/userbox';
# 	var boxOpen = false;
# 	var titleString='Most valuable players | Transfermarkt';
# 	var naviController = 'marktwertetop';
# 	var naviAction = 'wertvollstespieler';
# 	var naviPath = 'spieler-statistik/wertvollstespieler/marktwertetop';
# 	var naviId = '';
# 	var naviSaison = '';
# 	var onlyDE = '';
# 	var onlyMobile = '';
# 	var onlyTablet = '';
# 	var getUserID = '';
#
# function sendIvwData(typ) {
#     if(typeof iom === 'object' && typeof iom.c === 'function') {
#         if(typ == 'tabelle') {
#             var iam_data = {
# "st":"transfer",
# "cp":"ausland_co.uk_r_t",
# "oc":"co-uk_other",
# "mg":"yes",
# "sc":"yes",
# "sv":"i2",
# "co":""
# }
# iom.c(iam_data,1);
#
#         }else if(typ == 'reiter') {
#             var iam_data = {
# "st":"transfer",
# "cp":"ausland_co.uk_r_r",
# "oc":"co-uk_other",
# "mg":"yes",
# "sv":"i2",
# "sc":"yes",
# "co":""
# }
# iom.c(iam_data,1);
#
#         }else if(typ == 'forum') {
#             var iam_data = {
# "st":"transfer",
# "cp":"ausland_co.uk_r_forum",
# "oc":"co-uk_other",
# "mg":"yes",
# "sv":"i2",
# "sc":"yes",
# "co":""
# }
# iom.c(iam_data,1);
#
#         }else {
#             var iam_data = {
# "st":"transfer",
# "cp":"ausland_co.uk_r_s",
# "oc":"co-uk_other",
# "mg":"yes",
# "sv":"i2",
# "sc":"yes",
# "co":""
# }
# iom.c(iam_data,1);
#
#         }
#     }
# }
# jQuery(function($) {
# jQuery('#yw1').yiiGridView({'ajaxUpdate':['yw1'],'ajaxVar':'ajax','pagerClass':'pager','loadingClass':'grid\x2Dview\x2Dloading','filterClass':'filters','tableClass':'items','selectableRows':1,'enableHistory':false,'updateSelector':'\x7Bpage\x7D,\x20\x7Bsort\x7D','filterSelector':'\x7Bfilter\x7D','pageVar':'page'});
#
#           $(".spielprofil_tooltip").tooltipster({'position':'right','arrowColor':'white','delay':'100','speed':0,'contentAsHTML':true,'interactive':true,'content':'\x0A\x09\x09\x09\x3Cimg\x20src\x3D\x22https\x3A\x2F\x2Ftmssl.akamaized.net\x2F\x2Fimages\x2Fspinner.gif\x22\x20style\x3D\x22vertical\x2Dalign\x3A\x20middle\x3B\x22\x20\x2F\x3E\x0A\x09\x09','functionBefore':function(origin, continueTooltip) { continueTooltip(); id_array = origin.context.id.split("/"); var spieler_id = id_array[0]; $.post( "/spieler/_profilTooltip", { spieler_id : spieler_id }, function(data) { if(data) { origin.tooltipster("update", data); } }); }});
#
#
#           $(".vereinprofil_tooltip").tooltipster({'position':'right','arrowColor':'white','delay':'100','speed':0,'contentAsHTML':true,'interactive':true,'content':'\x0A\x09\x09\x09\x3Cimg\x20src\x3D\x22https\x3A\x2F\x2Ftmssl.akamaized.net\x2F\x2Fimages\x2Fspinner.gif\x22\x20style\x3D\x22vertical\x2Dalign\x3A\x20middle\x3B\x22\x20\x2F\x3E\x0A\x09\x09','functionBefore':function(origin, continueTooltip) { continueTooltip(); id_array = origin.context.id.split("/"); var verein_id = id_array[0]; $.post( "/verein/_profilTooltip", { verein_id : verein_id }, function(data) { if(data) { origin.tooltipster("update", data); } }); }});
#
# });
# /*]]>*/
# </script>
# </body>
# </html>

# %%
#선수들의 정보가 담긴 태그와 클래스 찾기
player_info = soup.find_all('tr',{'class':['odd','even']})

# %%
#첫 번째 요소 확인하기
print(player_info[0])

#전체 개수 확인하기
print(len(player_info))
#25개
# Out:
# <tr class="odd">
# <td class="zentriert">1</td><td class=""><table class="inline-table"><tr><td rowspan="2"><a href="#"><img alt="Kylian Mbappé" class="bilderrahmen-fixed" src="https://img.a.transfermarkt.technology/portrait/small/342229-1632686046.jpg?lm=1" title="Kylian Mbappé"/></a></td><td class="hauptlink"><a class="spielprofil_tooltip" href="/kylian-mbappe/profil/spieler/342229" id="342229" title="Kylian Mbappé">Kylian Mbappé</a></td></tr><tr><td>Centre-Forward</td></tr></table></td><td class="zentriert">22</td><td class="zentriert"><img alt="France" class="flaggenrahmen" src="https://tmssl.akamaized.net/images/flagge/verysmall/50.png?lm=1520611569" title="France"/></td><td class="zentriert"><a class="vereinprofil_tooltip" href="/fc-paris-saint-germain/startseite/verein/583" id="583"><img alt="Paris Saint-Germain" class="" src="https://tmssl.akamaized.net/images/wappen/verysmall/583.png?lm=1522312728" title=" "/></a></td><td class="rechts hauptlink"><b>€160.00m</b><span class="icons_sprite grey-block-ten" title="€160.00m"> </span></td></tr>
# 25

# %%
#7개 정보를 담을 빈 리스트 만들기 number , name, position, age,
#nation, team, value
number = []
name = []
position = []
age =[]
nation = []
team = []
value = []

# %%
#player_info에서 'td'태그만 모두 찾기
for info in player_info:
    player = info.find_all('td')
#해당 정보를 찾아서 각 리스트에 .append로 추가하기
    number.append(player[0].text)
    name.append(player[3].text)
    position.append(player[4].text)
    age.append(player[5].text)
    nation.append(player[6].img['alt'])
    team.append(player[7].img['alt'])
    value.append(player[8].text.strip())

# %%
#pd.DataFrame으로 저장하기
df = pd.DataFrame(
    {'number':number,
    'name':name,
    'position':position,
    'age':age,
    'nation':nation,
    'team':team,
    'value':value}
)
df
# Out:
#    number                    name            position age        nation  \
# 0       1           Kylian Mbappé      Centre-Forward  22        France
# 1       2          Erling Haaland      Centre-Forward  21        Norway
# 2       3              Harry Kane      Centre-Forward  28       England
# 3       4           Jack Grealish         Left Winger  26       England
# 4       5           Mohamed Salah        Right Winger  29         Egypt
# 5       6           Romelu Lukaku      Centre-Forward  28       Belgium
# 6       7         Kevin De Bruyne  Attacking Midfield  30       Belgium
# 7       8                  Neymar         Left Winger  29        Brazil
# 8       9            Jadon Sancho         Left Winger  21       England
# 9      10         Frenkie de Jong    Central Midfield  24   Netherlands
# 10     11         Bruno Fernandes  Attacking Midfield  27      Portugal
# 11     12          Joshua Kimmich  Defensive Midfield  26       Germany
# 12     13         Raheem Sterling         Left Winger  26       England
# 13     14         Marcus Rashford         Left Winger  24       England
# 14     15              Sadio Mané         Left Winger  29       Senegal
# 15     16           Heung-min Son         Left Winger  29  Korea, South
# 16     17                   Pedri    Central Midfield  18         Spain
# 17     18              Phil Foden    Central Midfield  21       England
# 18     19        Lautaro Martínez      Centre-Forward  24     Argentina
# 19     20         Marcos Llorente    Central Midfield  26         Spain
# 20     21            Lionel Messi        Right Winger  34     Argentina
# 21     22             Mason Mount  Attacking Midfield  22       England
# 22     23  Trent Alexander-Arnold          Right-Back  23       England
# 23     24              Rúben Dias         Centre-Back  24      Portugal
# 24     25              Marquinhos         Centre-Back  27        Brazil
#
#                    team     value
# 0   Paris Saint-Germain  €160.00m
# 1     Borussia Dortmund  €150.00m
# 2     Tottenham Hotspur  €120.00m
# 3       Manchester City  €100.00m
# 4          Liverpool FC  €100.00m
# 5            Chelsea FC  €100.00m
# 6       Manchester City  €100.00m
# 7   Paris Saint-Germain  €100.00m
# 8     Manchester United   €90.00m
# 9          FC Barcelona   €90.00m
# 10    Manchester United   €90.00m
# 11        Bayern Munich   €90.00m
# 12      Manchester City   €90.00m
# 13    Manchester United   €85.00m
# 14         Liverpool FC   €85.00m
# 15    Tottenham Hotspur   €85.00m
# 16         FC Barcelona   €80.00m
# 17      Manchester City   €80.00m
# 18          Inter Milan   €80.00m
# 19   Atlético de Madrid   €80.00m
# 20  Paris Saint-Germain   €80.00m
# 21           Chelsea FC   €75.00m
# 22         Liverpool FC   €75.00m
# 23      Manchester City   €75.00m
# 24  Paris Saint-Germain   €75.00m

# %%
#df.to_csv()로 csv파일로 저장하기
df.to_csv('transfermarkt25.csv',index =False)

# %% [markdown]
# - 두번째 페이지 까지 크롤링하기

# %%
headers = {'User-Agent':"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/95.0.4638.69 Safari/537.36"}
number = []
name = []
position = []
age =[]
nation = []
team = []
value = []

for i in range(1,3):
    url = f'https://www.transfermarkt.com/marktwertetop/wertvollstespieler?page={i}'
    r = requests.get(url,headers = headers)
    soup = BeautifulSoup(r.content,'html.parser')
    player_info = soup.find_all('tr',{'class':['odd','even']})

    for info in player_info:
        player = info.find_all('td')
        number.append(player[0].text)
        name.append(player[3].text)
        position.append(player[4].text)
        age.append(player[5].text)
        nation.append(player[6].img['alt'])
        team.append(player[7].img['alt'])
        value.append(player[8].text.strip())


df = pd.DataFrame(
    {'number':number,
    'name':name,
    'position':position,
    'age':age,
    'nation':nation,
    'team':team,
    'value':value},
)
df
df.to_csv('transfermarkt50.csv',index =False)
