# %% [markdown]
# ## 3.Matplotlib

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# %matplotlib inline  #inline에 표시(최신버전은 기본)

# %%
x = [100,200,300]
y = [1,2,3]
plt.plot(x,y)

# %%
#Series로 구현
value = pd.Series([1,2,3],[100,200,300])
plt.plot(value)

# %%
x = [100,200,300]
y = [1,2,3]
plt.plot(x,y,':r',linewidth =10) #빨간색 점선 굵기 10

# %%
x = [100,200,300]
y = [1,2,3]
plt.plot(x,y, color= '#ff0000',linewidth = 10)
plt.title('hello world',fontsize = 20)  #제목
plt.xlabel('hello',fontsize = 10)   #x라벨
plt.ylabel(' world',fontsize =10)   #y라벨
# Out:
# Text(0, 0.5, ' world')

# %%
x = [100,200,300]
y = [1,2,3]
plt.plot(x,y, color= '#ff0000',linewidth = 10)
plt.title('hello world',fontsize = 20)  #제목
plt.xlabel('hello',fontsize = 10)   #x라벨
plt.ylabel(' world',fontsize =10)   #y라벨
plt.savefig('sample.png')   #이미지로 저장

# %%
x = np.linspace(0,10,100)
y = np.sin(x)
y_ =np.cos(x)

plt.plot(x,y,label = 'sin')
plt.plot(x,y_,'-o',label = 'cos')

plt.legend(loc = 3) #라벨표시

# %% [markdown]
# ## scatter

# %%
x = np.linspace(0,10,20)
y = x**2

plt.scatter(x,y,c = 'r', alpha = 0.5)
plt.show()  #그래프 표시

# %% [markdown]
# ## histogram

# %%
x = [np.random.randint(1,7) for _ in range(100000)]

# %%
plt.hist(x, bins = 6)
plt.show()

# %% [markdown]
# ## Pie chart

# %%
labels = ['one','two','three']
size = [100,20,10]

plt.pie(size,labels = labels)
# Out:
# ([<matplotlib.patches.Wedge at 0x128ca1b5370>,
#   <matplotlib.patches.Wedge at 0x128cb5b5d00>,
#   <matplotlib.patches.Wedge at 0x128ca1b5c40>],
#  [Text(-0.8233618545088073, 0.7294348884854754, 'one'),
#   Text(0.6248713159427525, -0.905282187227813, 'two'),
#   Text(1.0680360337692223, -0.2632470903362633, 'three')])

# %%
labels = ['one','two','three']
size = [100,20,10]

plt.pie(size,labels = labels, shadow = True)    #그림자 생성
# Out:
# ([<matplotlib.patches.Wedge at 0x128cb575be0>,
#   <matplotlib.patches.Wedge at 0x128cb5758e0>,
#   <matplotlib.patches.Wedge at 0x128cb549460>],
#  [Text(-0.8233618545088073, 0.7294348884854754, 'one'),
#   Text(0.6248713159427525, -0.905282187227813, 'two'),
#   Text(1.0680360337692223, -0.2632470903362633, 'three')])

# %%
labels = ['one','two','three']
size = [100,20,10]

plt.pie(size,labels = labels, shadow = True,autopct = '%1.2f%%') #퍼센트생성
# Out:
# ([<matplotlib.patches.Wedge at 0x128cb344130>,
#   <matplotlib.patches.Wedge at 0x128cb2e28e0>,
#   <matplotlib.patches.Wedge at 0x128cb2e2af0>],
#  [Text(-0.8233618545088073, 0.7294348884854754, 'one'),
#   Text(0.6248713159427525, -0.905282187227813, 'two'),
#   Text(1.0680360337692223, -0.2632470903362633, 'three')],
#  [Text(-0.44910646609571303, 0.397873575537532, '76.92%'),
#   Text(0.34083889960513764, -0.4937902839424434, '15.38%'),
#   Text(0.5825651093286667, -0.14358932200159816, '7.69%')])

# %% [markdown]
# ## Bar Chart

# %%
plt.bar(['one','two','three'],[10,20,30])
plt.show()

# %%
plt.barh(['one','two','three'],[10,20,30])  #가로 바 그래프
plt.show()

# %% [markdown]
# ## 4.Plotly

# %%
import plotly.express as px #확장성이 더 좋다

x_ = np.array([1,2,3,4,5])
y_ = x**2

fig = px.line(x = x_,y = y_)
fig.show()

# %%
import plotly.graph_objects as go
korea_life = px.data.gapminder().query("country == 'Korea, Rep.'")
fig = px.line(korea_life, x = 'year',y = 'lifeExp',title = 'Life expectancy in Korea')
fig.show()

# %%
korea_life['year']
korea_life['lifeExp']
# Out:
# 840    47.453
# 841    52.681
# 842    55.292
# 843    57.716
# 844    62.612
# 845    64.766
# 846    67.123
# 847    69.810
# 848    72.244
# 849    74.647
# 850    77.045
# 851    78.623
# Name: lifeExp, dtype: float64

# %%
korea_gdp = px.data.gapminder().query("country == 'Korea, Rep.'")
fig = px.bar(korea_gdp, x= 'year',y= 'gdpPercap',title = '한국인 GDP')
fig.show()

# %%
korea_gdp = px.data.gapminder().query("country == 'Korea, Rep.'")
fig = px.scatter(korea_gdp, x= 'year',y= 'gdpPercap',title = '한국인 GDP')
fig.show()
#산점도

# %% [markdown]
# ## 이미지 분석

# %%
from skimage import io
#from PIL import Image
#from cv2

# %%
jeju = io.imread('jeju.jpg')
type(jeju)
# Out:
# numpy.ndarray

# %%
jeju.shape
# Out:
# (853, 1280, 3)

# %%
jeju
# Out:
# array([[[  0,  48, 110],
#         [  3,  51, 113],
#         [  2,  50, 112],
#         ...,
#         [  8,  23,  56],
#         [ 10,  25,  58],
#         [ 12,  27,  60]],
#
#        [[  0,  47, 109],
#         [  1,  49, 111],
#         [  0,  48, 110],
#         ...,
#         [  7,  22,  55],
#         [  9,  24,  57],
#         [ 11,  26,  59]],
#
#        [[  0,  47, 109],
#         [  0,  48, 110],
#         [  0,  48, 110],
#         ...,
#         [  6,  21,  54],
#         [  8,  23,  56],
#         [ 10,  25,  58]],
#
#        ...,
#
#        [[ 14,  67, 119],
#         [ 13,  66, 118],
#         [ 11,  64, 116],
#         ...,
#         [ 15,  36,  65],
#         [ 14,  35,  64],
#         [ 11,  32,  61]],
#
#        [[ 15,  68, 120],
#         [ 13,  66, 118],
#         [ 11,  64, 116],
#         ...,
#         [ 15,  36,  65],
#         [ 15,  36,  65],
#         [ 13,  34,  63]],
#
#        [[ 16,  69, 121],
#         [ 13,  66, 118],
#         [ 11,  64, 116],
#         ...,
#         [ 15,  36,  65],
#         [ 16,  37,  66],
#         [ 15,  36,  65]]], dtype=uint8)

# %%
np.min(jeju),np.max(jeju)
# Out:
# (0, 255)

# %%
plt.imshow(jeju)

# %%
plt.imshow(jeju[::-1]) #상하 좌우 반전

# %%
plt.imshow(jeju[:,::-1])    #좌우 반전

# %%
plt.imshow(jeju[::-1,:]) #상하반전

# %%
plt.imshow(jeju[100:660,100:1200])
#이미지 자르기

# %%
plt.imshow(jeju[::3,::3])    #3칸씩 건너뜀

# %%
plt.imshow(jeju[::10,::10])    #10칸씩 건너뜀 픽셀 깨짐

# %%
minijeju = jeju[::10,::10]

# %%
plt.hist(minijeju.ravel(),256,[0,256])
plt.show()

# %%
#특정값 이하 편집
minijeju_= np.where(minijeju<50,minijeju,0)
#minijeju가 50 보다 작으면 minijeju 그대로 아니면 0
plt.imshow(minijeju_)

# %%
#색상변경
plt.imshow(jeju[:,:,0])

# %%
plt.imshow(jeju[:,:,1])

# %%
plt.imshow(jeju[:,:,2])

# %%
#회색 계열 변경
from skimage import color
plt.imshow(color.rgb2gray(jeju),cmap=plt.cm.gray)
